# %% [markdown]
# <a href="https://colab.research.google.com/github/Umesh06ds/python-fundamentals/blob/main/python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as
# Out:
#   File "<ipython-input-1-c315ab3cee86>", line 1
#     import pandas as
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df.read_csv('Salaries.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2329165885bd> in <cell line: 1>()
# ----> 1 df.read_csv('Salaries.csv')
#
# NameError: name 'df' is not defined

# %%
pd.read_csv('Salaries.csv')
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
'df'
# Out:
# 'df'

# %%
df.insull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cb0bf09c922f> in <cell line: 1>()
# ----> 1 df.insull()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ea8415b8a3ee> in <cell line: 1>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('Salaries.csv')

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.insull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cb0bf09c922f> in <cell line: 1>()
# ----> 1 df.insull()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'insull'

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.isnull().any()
# Out:
# rank          False
# discipline    False
# phd           False
# service       False
# sex           False
# salary        False
# dtype: bool

# %%
df['rank'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f028d57ee4e0> in <cell line: 1>()
# ----> 1 df['rank'].mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].min()
# Out:
# 57800

# %%
# prompt: can you find out mean, median, mode, standard deviation, variance for the given data

import pandas as pd

# Load the dataset (assuming 'Salaries.csv' is in the current directory)
df = pd.read_csv('Salaries.csv')

# Calculate mean, median, mode, standard deviation, and variance for the 'salary' column
mean_salary = df['salary'].mean()
median_salary = df['salary'].median()
mode_salary = df['salary'].mode()
std_salary = df['salary'].std()
var_salary = df['salary'].var()

# Print the results
print(f"Mean salary: {mean_salary}")
print(f"Median salary: {median_salary}")
print(f"Mode salary: {mode_salary}")
print(f"Standard deviation of salary: {std_salary}")
print(f"Variance of salary: {var_salary}")
# Out:
# Mean salary: 108023.78205128205
# Median salary: 104671.0
# Mode salary: 0    92000
# Name: salary, dtype: int64
# Standard deviation of salary: 28293.661022264165
# Variance of salary: 800531254.0427904

# %%
df.['salary']>50000
# Out:
#   File "<ipython-input-22-a2d067876350>", line 1
#     df.['salary']>50000
#        ^
# SyntaxError: invalid syntax

# %%
df[df['salary']>50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df[df['salary']>50000
# Out:
#   File "<ipython-input-24-1202cc42bb75>", line 1
#     df[df['salary']>50000
#                          ^
# SyntaxError: incomplete input

# %%
df['salary'] > 50000
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# Name: salary, Length: 78, dtype: bool

# %%
df.iloc[0:13:]
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000

# %%
import matplotlib_inline as plt

# %%
plt.read_csv('Salaries.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-277acbe49032> in <cell line: 1>()
# ----> 1 plt.read_csv('Salaries.csv')
#
# AttributeError: module 'matplotlib_inline' has no attribute 'read_csv'

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df1['SAT'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-1aba19e92499> in <cell line: 1>()
# ----> 1 plt.bar(df1['SAT'])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
# prompt: plot a bar graph of SAT column from the above data

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df1 = pd.read_csv('Universities.csv')

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
plt.bar(df1.index, df1['SAT'])
plt.xlabel('University Index')
plt.ylabel('SAT Score')
plt.title('SAT Scores of Universities')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
plt.plot(df1['SAT'])

# %%
sns.pairplot(df1)['SAT']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-70f38e172c09> in <cell line: 1>()
# ----> 1 sns.pairplot(df1)['SAT']
#
# TypeError: 'PairGrid' object is not subscriptable

# %%
# prompt: create pair plot of histogram and scatter plot on SAT column for the above data

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df1 is already loaded as shown in the previous code
# df1 = pd.read_csv('Universities.csv')

# Create the pair plot with histograms and scatter plots for the 'SAT' column
sns.pairplot(df1, vars=['SAT'], diag_kind='hist')
plt.show()

# %%
sns.pairplot(df1, vars=['SAT'], diag_kind='hist')
plt.show()

# %%
sns.pairplot(df1['SAT'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f20c2fab50fc> in <cell line: 1>()
# ----> 1 sns.pairplot(df1['SAT'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2101
#    2102     if not isinstance(data, pd.DataFrame):
# -> 2103         raise TypeError(
#    2104             f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2105
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
sns.distplot(df1['SAT'])
# Out:
# <ipython-input-45-89755ed31036>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['SAT'])
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
plt.boxplot(df1['SAT'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79d7a36c6650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79d7a36c4b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79d7a36c5ea0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79d7a36c4e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79d7a36c69e0>],
#  'means': []}

# %%
import numpy as np

# %%
b = np.array([1,2,3,4,5])

# %%
b.shape
# Out:
# (5,)

# %%
b.size
# Out:
# 5

# %%
b.sum()
# Out:
# 15

# %%
b.var()
# Out:
# 2.0

# %%
b.std()
# Out:
# 1.4142135623730951

# %%
c = np.array([(2,5,6,7),(1,4,8,3)])

# %%
c.shape
# Out:
# (2, 4)

# %%
c= c.reshape(4,2)

# %%
c.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-86df1d1172c0> in <cell line: 1>()
# ----> 1 c.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'

# %%
c
# Out:
# array([[2, 5],
#        [6, 7],
#        [1, 4],
#        [8, 3]])

# %%
b.sum(axis=0)
# Out:
# 15

# %%
c.sum(axis=0)
# Out:
# array([17, 19])

# %%
c.sum(axis=1)
# Out:
# array([ 7, 13,  5, 11])

# %%
c[1,1]
# Out:
# 7

# %%
c[0,0]
# Out:
# 2
